# %%
#import sys
#!{sys.executable} -m pip install folium

#import sys
#!{sys.executable} -m pip install import_ipynb
from folium import Map, Marker, Icon, FeatureGroup, LayerControl, Choropleth
from folium.plugins import HeatMap
from folium.vector_layers import Circle, Polygon
import pandas as pd
import import_ipynb
import queries

#mientras cargaba el jupiter "queries" me he quedado sin tokens por lo que no he podido cargarlo completamente
# y no he podido progresar mucho más.

# %%
# Ubicamos en el mapa la oficina que tenia la mejor puntuación.

z = Map(location=[42.35888, -71.05682],zoom_start=15)
z

c = Circle(location=[42.35888, -71.05682],radius=80)
c.add_to(z)
z
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
starbucks_coordinates = starbucks_within_1km(42.35888, -71.05682)
starbucks_coordinates
# Out:
# [(42.35814839, -71.05817074),
#  (42.35914156082082, -71.05554804778141),
#  (42.35938374, -71.05930244)]

# %%
df = pd.DataFrame(starbucks_coordinates, columns = ["Latitude", "Longitude"])
# We will show the schools around our office:
df
# Out:
#     Latitude  Longitude
# 0  42.358148 -71.058171
# 1  42.359142 -71.055548
# 2  42.359384 -71.059302

# %%
# We will show the starbucks around our office:

for i, row in df.iterrows():
    starbucks = {
        "location" : [row["Latitude"], row["Longitude"]],
        }
    ic = Icon(color = "green",
             prefix ="fa",
             icon = "coffee",
             icon_color = "white")
    Marker(**starbucks, icon = ic).add_to(z)
z
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
education_coordinates = education_within_2km(42.35888, -71.05682)

df1 = pd.DataFrame(education_coordinates, columns = ["Latitude", "Longitude"])
df1
# Out:
#     Latitude  Longitude
# 0  42.363915 -71.053221
# 1  42.366093 -71.053374
# 2  42.366131 -71.053474
# 3  42.365978 -71.054932
# 4  42.356540 -71.071674

# %%
# We will show the schools around our office:
for i, row in df1.iterrows():
    education = {
        "location" : [row["Latitude"], row["Longitude"]],
        }
    ic = Icon(color = "orange",
             prefix ="fa",
             icon = "book",
             icon_color = "black")
    Marker(**education, icon = ic).add_to(z)
z
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
nightlife_spots_coordinates = nightlife_spots_within_2km(42.35888, -71.05682)

df2 = pd.DataFrame(nightlife_spots_coordinates, columns = ["Latitude", "Longitude"])
df2
# Out:
#     Latitude  Longitude
# 0  42.357574 -71.059495
# 1  42.356540 -71.051100
# 2  42.355664 -71.061466
# 3  42.359135 -71.054298
# 4  42.359071 -71.059173
# 5  42.357783 -71.053553
# 6  42.359400 -71.054171
# 7  42.361371 -71.057152
# 8  42.359310 -71.053593
# 9  42.357923 -71.059917

# %%
# We will show the bars & clubs around our office:
for i, row in df2.iterrows():
    nightlife_spots = {
        "location" : [row["Latitude"], row["Longitude"]],
        }
    ic = Icon(color = "white",
             prefix ="fa",
             icon = "glass",
             icon_color = "black")
    Marker(**nightlife_spots, icon = ic).add_to(z)
z
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
startups_coordinates = startups_raised_over_1m_within_2km(42.35888, -71.05682)

df3 = pd.DataFrame(startups_coordinates, columns = ["Latitude", "Longitude"])
df3
# Out:
#     Latitude  Longitude
# 0  42.358880 -71.056820
# 1  42.358880 -71.056820
# 2  42.358880 -71.056820
# 3  42.358920 -71.057810
# 4  42.358920 -71.057810
# 5  42.358920 -71.057810
# 6  42.358920 -71.057810
# 7  42.358431 -71.059773
# 8  42.358431 -71.059773
# 9  42.358431 -71.059773

# %%
# We will show the startups that raised over 1M around our office:
for i, row in df3.iterrows():
    startups = {
        "location" : [row["Latitude"], row["Longitude"]],
        }
    ic = Icon(color = "black",
             prefix ="fa",
             icon = "rocket",
             icon_color = "white")
    Marker(**startups, icon = ic).add_to(z)
z
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
game_design_coordinates = game_design_companies_within_2km(42.35888, -71.05682)

df4 = pd.DataFrame(game_design_coordinates, columns = ["Latitude", "Longitude"])
df4
# Out:
#      Latitude  Longitude
# 0   42.352835 -71.060961
# 1   42.352835 -71.060961
# 2   42.352835 -71.060961
# 3   42.352835 -71.060961
# 4   42.352835 -71.060961
# 5   42.352835 -71.060961
# 6   42.350274 -71.058768
# 7   42.350274 -71.058768
# 8   42.350274 -71.058768
# 9   42.350274 -71.058768
# 10  42.352096 -71.064632
# 11  42.352096 -71.064632
# 12  42.352096 -71.064632
# 13  42.352096 -71.064632

# %%
# We will show the startups that raised over 1M around our office:
for i, row in df4.iterrows():
    game_design_companies = {
        "location" : [row["Latitude"], row["Longitude"]],
        }
    ic = Icon(color = "red",
             prefix ="fa",
             icon = "gamepad",
             icon_color = "white")
    Marker(**game_design_companies, icon = ic).add_to(z)
z
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
airports_coordinates = airports_within_25km(42.35888, -71.05682)

df5 = pd.DataFrame(airports_coordinates, columns = ["Latitude", "Longitude"])
df5
# Out:
#    Latitude  Longitude
# 0  42.36514 -71.018887

# %%
# We will try to show the airports within 25km distance from our office:
for i, row in df5.iterrows():
    airport = {
        "location" : [row["Latitude"], row["Longitude"]],
        }
    ic = Icon(color = "lightgray",
             prefix ="fa",
             icon = "plane",
             icon_color = "white")
    Marker(**airport, icon = ic).add_to(z)
z
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
basketball_stadium_coordinates = basketball_stadium_within_10km(42.35888, -71.05682)

df6 = pd.DataFrame(basketball_stadium_coordinates, columns = ["Latitude", "Longitude"])
df6
# Out:
#     Latitude  Longitude
# 0  42.366329 -71.062153

# %%
# We will try to show the basketball stadiums around our office:
for i, row in df6.iterrows():
    basketball = {
        "location" : [row["Latitude"], row["Longitude"]],
        }
    ic = Icon(color = "blue",
             prefix ="fa",
             icon = "futbol-o",
             icon_color = "white")
    Marker(**basketball, icon = ic).add_to(z)
z
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
pet_services_coordinates = pet_services_within_1km(42.35888, -71.05682)

df7 = pd.DataFrame(pet_services_coordinates, columns = ["Latitude", "Longitude"])
df7
# Out:
#     Latitude  Longitude
# 0  42.360161 -71.059227

# %%
# We will try to show the pet services around our office:
for i, row in df7.iterrows():
    pet_services = {
        "location" : [row["Latitude"], row["Longitude"]],
        }
    ic = Icon(color = "pink",
             prefix ="fa",
             icon = "scissors",
             icon_color = "black")
    Marker(**pet_services, icon = ic).add_to(z)
z
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
vegan_restaurants_coordinates = vegan_restaurants_within_1km(42.35888, -71.05682)

df8 = pd.DataFrame(vegan_restaurants_coordinates, columns = ["Latitude", "Longitude"])
df8
# Out:
#     Latitude  Longitude
# 0  42.357685 -71.058755
# 1  42.353715 -71.056216
# 2  42.357674 -71.059306

# %%
# We will try to show the vegan restaurants around our office:
for i, row in df8.iterrows():
    vegan_places = {
        "location" : [row["Latitude"], row["Longitude"]],
        }
    ic = Icon(color = "lightred",
             prefix ="fa",
             icon = "spoon",
             icon_color = "black")
    Marker(**vegan_places, icon = ic).add_to(z)
z
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# I wanted to find and use different maps but ran out of time so this is the only map I could
# show. I needed more time to develop more the project...
